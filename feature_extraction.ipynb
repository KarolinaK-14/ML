# %% [markdown]
# <a href="https://colab.research.google.com/github/KarolinaK-14/ML/blob/main/feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### scikit-learn
# Library page: [https://scikit-learn.org](https://scikit-learn.org)
#
# Documentation/User Guide: [https://scikit-learn.org/stable/user_guide.html](https://scikit-learn.org/stable/user_guide.html)
#
# The core library for machine learning in Python.
#
# To install the library, use the command below:
# ```
# !pip install scikit-learn
# ```
# To update the library to the latest version, use the command below:
# ```
# !pip install --upgrade scikit-learn
# ```
# ### Table of contents:
# 1. [Importing libraries](#0)
# 2. [Loading data](#1)
# 3. [Creating a copy of the data](#2)
# 4. [Generating new variables](#3)
# 5. [Discretization of a continuous variable](#4)
# 6. [Feature extraction](#5)

# %% [markdown]
# ### <a name='0'></a> Importing libraries

# %%
import numpy as np
import pandas as pd
import sklearn

# %% [markdown]
# ### <a name='1'></a> Loading data

# %%
def fetch_financial_data(company='AMZN'):
    """
    This function fetches stock market quotations.
    """
    import pandas_datareader.data as web
    return web.DataReader(name=company, data_source='stooq')

df_raw = fetch_financial_data()
df_raw.head()
# Out:
#                Open      High     Low   Close    Volume
# Date
# 2025-05-23  198.900  202.3700  197.85  200.99  33393545
# 2025-05-22  201.380  205.7600  200.16  203.10  38938882
# 2025-05-21  201.610  203.4550  200.06  201.12  42460924
# 2025-05-20  204.628  205.5899  202.65  204.07  29470373
# 2025-05-19  201.645  206.6200  201.26  206.16  34314810

# %% [markdown]
# ### <a name='2'></a> Creating a copy of the data

# %%
df = df_raw.copy()
df = df[:5]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2025-05-23 to 2025-05-19
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5 non-null      float64
#  1   High    5 non-null      float64
#  2   Low     5 non-null      float64
#  3   Close   5 non-null      float64
#  4   Volume  5 non-null      int64
# dtypes: float64(4), int64(1)
# memory usage: 240.0 bytes

# %% [markdown]
# ### <a name='3'></a> Generating new variables

# %%
df.index.month
# Out:
# Index([5, 5, 5, 5, 5], dtype='int32', name='Date')

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df
# Out:
#                Open      High     Low   Close    Volume  day  month  year
# Date
# 2025-05-23  198.900  202.3700  197.85  200.99  33393545   23      5  2025
# 2025-05-22  201.380  205.7600  200.16  203.10  38938882   22      5  2025
# 2025-05-21  201.610  203.4550  200.06  201.12  42460924   21      5  2025
# 2025-05-20  204.628  205.5899  202.65  204.07  29470373   20      5  2025
# 2025-05-19  201.645  206.6200  201.26  206.16  34314810   19      5  2025

# %% [markdown]
# ### <a name='4'></a> Discretization of a continuous variable

# %%
df = pd.DataFrame(data={'height': [175., 178.5, 185., 191., 184.5, 183., 168.]})
df
# Out:
#    height
# 0   175.0
# 1   178.5
# 2   185.0
# 3   191.0
# 4   184.5
# 5   183.0
# 6   168.0

# %%
df['height_cat'] = pd.cut(x=df.height, bins=(160, 175, 190, 260), labels=['short', 'tall', 'very tall'])
df
# Out:
#    height height_cat
# 0   175.0      short
# 1   178.5       tall
# 2   185.0       tall
# 3   191.0  very tall
# 4   184.5       tall
# 5   183.0       tall
# 6   168.0      short

# %%
pd.get_dummies(df, drop_first=True, prefix='height', dtype=int)
# Out:
#    height  height_tall  height_very tall
# 0   175.0            0                 0
# 1   178.5            1                 0
# 2   185.0            1                 0
# 3   191.0            0                 1
# 4   184.5            1                 0
# 5   183.0            1                 0
# 6   168.0            0                 0

# %% [markdown]
# ### <a name='5'></a> Feature extraction

# %%
df = pd.DataFrame(data={'lang': [['PL', 'ENG'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]})
df
# Out:
#                   lang
# 0            [PL, ENG]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %%
df['lang_number'] = df['lang'].apply(len)

# %%
df
# Out:
#                   lang  lang_number
# 0            [PL, ENG]            2
# 1  [GER, ENG, PL, FRA]            4
# 2                [RUS]            1

# %%
df['PL_lag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                   lang  lang_number  PL-flag  PL_lag
# 0            [PL, ENG]            2        1       1
# 1  [GER, ENG, PL, FRA]            4        1       1
# 2                [RUS]            1        0       0

# %%
del df['PL-flag']
df
# Out:
#                   lang  lang_number  PL_lag
# 0            [PL, ENG]            2       1
# 1  [GER, ENG, PL, FRA]            4       1
# 2                [RUS]            1       0

# %%
df.pop('PL_lag')
# Out:
# 0    1
# 1    1
# 2    0
# Name: PL_lag, dtype: int64

# %%
df
# Out:
#                   lang  lang_number
# 0            [PL, ENG]            2
# 1  [GER, ENG, PL, FRA]            4
# 2                [RUS]            1

# %%
df['PL_flag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                   lang  lang_number  PL_flag
# 0            [PL, ENG]            2        1
# 1  [GER, ENG, PL, FRA]            4        1
# 2                [RUS]            1        0

# %%
df = pd.DataFrame(data={'website': ['wp.pl', 'onet.pl', 'google.com']})
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df.website.str.split('.', expand=True)
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df.website.str.split('.', expand=True)
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
new = df.website.str.split('.', expand=True)
df['portal'] = new[0]
df['extension'] = new[1]
df
# Out:
#       website  portal extension
# 0       wp.pl      wp        pl
# 1     onet.pl    onet        pl
# 2  google.com  google       com

# %%
print (new.info)
# Out:
# <bound method DataFrame.info of         0    1
# 0      wp   pl
# 1    onet   pl
# 2  google  com>
